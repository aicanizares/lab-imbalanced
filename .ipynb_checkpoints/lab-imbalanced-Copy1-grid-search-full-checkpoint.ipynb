# %% [markdown]
# # LAB | Imbalanced

# %% [markdown]
# **Load the data**
#
# In this challenge, we will be working with Credit Card Fraud dataset.
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/card_transdata.csv
#
# Metadata
#
# - **distance_from_home:** the distance from home where the transaction happened.
# - **distance_from_last_transaction:** the distance from last transaction happened.
# - **ratio_to_median_purchase_price:** Ratio of purchased price transaction to median purchase price.
# - **repeat_retailer:** Is the transaction happened from same retailer.
# - **used_chip:** Is the transaction through chip (credit card).
# - **used_pin_number:** Is the transaction happened by using PIN number.
# - **online_order:** Is the transaction an online order.
# - **fraud:** Is the transaction fraudulent. **0=legit** -  **1=fraud**

# %%
#Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_fraud = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/card_transdata.csv")
df_fraud.head()

# %% [markdown]
# **Steps:**

# %% [markdown]
# - **1.** What is the distribution of our target variable? Can we say we're dealing with an imbalanced dataset?
# - **2.** Train a LogisticRegression.
# - **3.** Evaluate your model. Take in consideration class importance, and evaluate it by selection the correct metric.
# - **4.** Run **Oversample** in order to balance our target variable and repeat the steps above, now with balanced data. Does it improve the performance of our model?
# - **5.** Now, run **Undersample** in order to balance our target variable and repeat the steps above (1-3), now with balanced data. Does it improve the performance of our model?
# - **6.** Finally, run **SMOTE** in order to balance our target variable and repeat the steps above (1-3), now with balanced data. Does it improve the performance of our model?

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import precision_score, recall_score, classification_report, confusion_matrix, f1_score
from sklearn.preprocessing import StandardScaler

from sklearn.utils import resample

# %%
df_fraud.isnull().sum()
# Out:
# distance_from_home                0
# distance_from_last_transaction    0
# ratio_to_median_purchase_price    0
# repeat_retailer                   0
# used_chip                         0
# used_pin_number                   0
# online_order                      0
# fraud                             0
# dtype: int64

# %%
df_fraud.shape
# Out:
# (1000000, 8)

# %%
df_fraud["fraud"].value_counts()
# Out:
# fraud
# 0.0    912597
# 1.0     87403
# Name: count, dtype: int64

# %%
# 1. What is the distribution of our target variable? Can we say we're dealing with an imbalanced dataset?
# Yes, because 91.26 % of the values for the column "fraud" are False.

# 2. Train a LogisticRegression.
# For baseline, we will train a Logistic Regression in imbalanced data.

# %%
cl_fraud = df_fraud["fraud"].value_counts()
cl_fraud.plot(kind="bar")
plt.show()

# %%
features = df_fraud.drop(columns = ["fraud"])
target = df_fraud["fraud"]

X_train, X_test, y_train, y_test = train_test_split(features, target)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
log_reg.score(X_test_scaled, y_test)
# Out:
# 0.95836

# %%
pred = log_reg.predict(X_test_scaled)
print(classification_report(y_pred = pred, y_true = y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98    228081
#          1.0       0.89      0.60      0.72     21919
#
#     accuracy                           0.96    250000
#    macro avg       0.93      0.80      0.85    250000
# weighted avg       0.96      0.96      0.95    250000

# %%
# 3. Evaluate your model. Take in consideration class importance, and evaluate it by selection the correct metric.
# High Accuracy (95.91%) → The model correctly classifies most cases.
# Precision for Class 1 (Fraud): 89%. When the model predicts fraud, it is correct 89% of the time.
# Recall for Class 1 (Fraud): 60% The model misses 40% of actual fraud cases. Recall of fraud matters more than overall accuracy.

# %%
# 4. Run Oversample in order to balance our target variable and repeat the steps above, now with balanced data. Does it improve the model's performance?

# %%
train = pd.DataFrame(X_train_scaled, columns = X_train.columns)

# %%
train["fraud"] = y_train.values

# %%
# Add the target column "fraud" manually before resampling.

# %%
print(train.columns)  # Verify if "fraud" is present
# Out:
# Index(['distance_from_home', 'distance_from_last_transaction',
#        'ratio_to_median_purchase_price', 'repeat_retailer', 'used_chip',
#        'used_pin_number', 'online_order', 'fraud'],
#       dtype='object')

# %%
train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
train["fraud"] = y_train.values

# %%
print(train.columns)
# Out:
# Index(['distance_from_home', 'distance_from_last_transaction',
#        'ratio_to_median_purchase_price', 'repeat_retailer', 'used_chip',
#        'used_pin_number', 'online_order', 'fraud'],
#       dtype='object')

# %%
true = train[train["fraud"] == 1]
false = train[train["fraud"] == 0]

# %%
true_oversampled = resample(true, 
                                    replace=True, 
                                    n_samples = len(false),
                                    random_state=0)

# %%
train_over = pd.concat([true_oversampled, false])
train_over
# Out:
#         distance_from_home  distance_from_last_transaction  \
# 32086            -0.265364                        0.031160
# 497849           -0.213026                        0.416327
# 486627           -0.372743                       -0.185873
# 600238           -0.077338                       -0.165072
# 525319           -0.321482                       -0.181287
# ...                    ...                             ...
# 749995           -0.353256                        1.331665
# 749996           -0.336696                       -0.173099
# 749997           -0.331239                       -0.163708
# 749998           -0.094153                       -0.172251
# 749999           -0.077328                       -0.172457
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 32086                         3.481438         0.366488  -0.733823
# 497849                        1.262554         0.366488  -0.733823
# 486627                        1.146349         0.366488  -0.733823
# 600238                        0.835070         0.366488  -0.733823
# 525319                        1.235551         0.366488   1.362726
# ...                                ...              ...        ...
# 749995                       -0.361984         0.366488  -0.733823
# 749996                        0.217475         0.366488  -0.733823
# 749997                       -0.615171         0.366488   1.362726
# 749998                       -0.218436         0.366488  -0.733823
# 749999                       -0.357366         0.366488  -0.733823
#
#         used_pin_number  online_order  fraud
# 32086         -0.335091      0.733537    1.0
# 497849        -0.335091      0.733537    1.0
# 486627        -0.335091      0.733537    1.0
# 600238        -0.335091      0.733537    1.0
# 525319        -0.335091      0.733537    1.0
# ...                 ...           ...    ...
# 749995        -0.335091     -1.363258    0.0
# 749996        -0.335091      0.733537    0.0
# 749997        -0.335091      0.733537    0.0
# 749998        -0.335091     -1.363258    0.0
# 749999        -0.335091      0.733537    0.0
#
# [1369032 rows x 8 columns]

# %%
true_plt = train_over["fraud"].value_counts()
true_plt.plot(kind="bar")
plt.show()

# %%
features = df_fraud.drop(columns = ["fraud"])
target = df_fraud["fraud"]

X_train, X_test, y_train, y_test = train_test_split(features, target)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
log_reg.score(X_test_scaled, y_test)
# Out:
# 0.958732

# %%
pred = log_reg.predict(X_test_scaled)
print(classification_report(y_pred = pred, y_true = y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98    228130
#          1.0       0.89      0.60      0.72     21870
#
#     accuracy                           0.96    250000
#    macro avg       0.93      0.80      0.85    250000
# weighted avg       0.96      0.96      0.96    250000

# %%
# 4. Overall accuracy remains high (96%), meaning the model is still performing well.
# Precision for Fraud (Class 1) improved slightly (89%), indicating better fraud identification.
# Recall for Fraud (Class 1) stayed the same (60%), meaning the model still misses 40% of actual fraud cases.
# Macro Avg Recall (80%) improved compared to the imbalanced version (previously lower).

# %%
# 5. Now, run Undersample in order to balance our target variable and repeat the steps above (1-3), now with balanced data. Does it improve the performance of our model?

# %%
train
# Out:
#         distance_from_home  distance_from_last_transaction  \
# 0                 0.476305                       -0.176626
# 1                 0.340308                       -0.162331
# 2                -0.386253                       -0.175803
# 3                 0.416079                       -0.181288
# 4                -0.357926                       -0.126334
# ...                    ...                             ...
# 749995           -0.353256                        1.331665
# 749996           -0.336696                       -0.173099
# 749997           -0.331239                       -0.163708
# 749998           -0.094153                       -0.172251
# 749999           -0.077328                       -0.172457
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 0                            -0.348989         0.366488  -0.733823
# 1                             0.381080         0.366488   1.362726
# 2                            -0.124925        -2.728604   1.362726
# 3                            -0.489885         0.366488  -0.733823
# 4                            -0.133431         0.366488  -0.733823
# ...                                ...              ...        ...
# 749995                       -0.361984         0.366488  -0.733823
# 749996                        0.217475         0.366488  -0.733823
# 749997                       -0.615171         0.366488   1.362726
# 749998                       -0.218436         0.366488  -0.733823
# 749999                       -0.357366         0.366488  -0.733823
#
#         used_pin_number  online_order  fraud
# 0             -0.335091     -1.363258    0.0
# 1             -0.335091      0.733537    0.0
# 2              2.984263     -1.363258    0.0
# 3             -0.335091      0.733537    0.0
# 4             -0.335091      0.733537    0.0
# ...                 ...           ...    ...
# 749995        -0.335091     -1.363258    0.0
# 749996        -0.335091      0.733537    0.0
# 749997        -0.335091      0.733537    0.0
# 749998        -0.335091     -1.363258    0.0
# 749999        -0.335091      0.733537    0.0
#
# [750000 rows x 8 columns]

# %%
false_undersampled = resample(false, 
                                    replace=False, 
                                    n_samples = len(true),
                                    random_state=0)
false_undersampled
# Out:
#         distance_from_home  distance_from_last_transaction  \
# 454339            0.057644                        0.432312
# 427325           -0.254197                       -0.181510
# 43784            -0.286641                       -0.158310
# 701076           -0.269713                       -0.140761
# 653314            0.518111                       -0.177031
# ...                    ...                             ...
# 84019             0.579924                        0.192159
# 321148           -0.310250                       -0.184558
# 25181            -0.229228                       -0.186069
# 698361           -0.297587                        0.259888
# 71671            -0.369842                       -0.175055
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 454339                       -0.211849         0.366488   1.362726
# 427325                       -0.562344         0.366488   1.362726
# 43784                         0.102845         0.366488   1.362726
# 701076                       -0.591297         0.366488  -0.733823
# 653314                       -0.299910         0.366488  -0.733823
# ...                                ...              ...        ...
# 84019                        -0.323874         0.366488  -0.733823
# 321148                        1.152666         0.366488  -0.733823
# 25181                        -0.234947         0.366488   1.362726
# 698361                       -0.540690         0.366488   1.362726
# 71671                        -0.386795         0.366488  -0.733823
#
#         used_pin_number  online_order  fraud
# 454339        -0.335091      0.733537    0.0
# 427325        -0.335091      0.733537    0.0
# 43784          2.984263      0.733537    0.0
# 701076        -0.335091      0.733537    0.0
# 653314        -0.335091      0.733537    0.0
# ...                 ...           ...    ...
# 84019         -0.335091      0.733537    0.0
# 321148         2.984263      0.733537    0.0
# 25181         -0.335091      0.733537    0.0
# 698361        -0.335091      0.733537    0.0
# 71671          2.984263     -1.363258    0.0
#
# [65484 rows x 8 columns]

# %%
train_under = pd.concat([false_undersampled, true])
train_under
# Out:
#         distance_from_home  distance_from_last_transaction  \
# 454339            0.057644                        0.432312
# 427325           -0.254197                       -0.181510
# 43784            -0.286641                       -0.158310
# 701076           -0.269713                       -0.140761
# 653314            0.518111                       -0.177031
# ...                    ...                             ...
# 749925           -0.363913                       -0.135560
# 749926            1.900209                       -0.177377
# 749969           -0.400176                       -0.178159
# 749980            2.082572                       -0.183930
# 749994            1.624916                       -0.115380
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 454339                       -0.211849         0.366488   1.362726
# 427325                       -0.562344         0.366488   1.362726
# 43784                         0.102845         0.366488   1.362726
# 701076                       -0.591297         0.366488  -0.733823
# 653314                       -0.299910         0.366488  -0.733823
# ...                                ...              ...        ...
# 749925                        2.110848         0.366488   1.362726
# 749926                       -0.483565         0.366488  -0.733823
# 749969                        1.180545        -2.728604   1.362726
# 749980                       -0.439887         0.366488  -0.733823
# 749994                        0.514837         0.366488  -0.733823
#
#         used_pin_number  online_order  fraud
# 454339        -0.335091      0.733537    0.0
# 427325        -0.335091      0.733537    0.0
# 43784          2.984263      0.733537    0.0
# 701076        -0.335091      0.733537    0.0
# 653314        -0.335091      0.733537    0.0
# ...                 ...           ...    ...
# 749925        -0.335091      0.733537    1.0
# 749926        -0.335091      0.733537    1.0
# 749969        -0.335091      0.733537    1.0
# 749980        -0.335091      0.733537    1.0
# 749994        -0.335091      0.733537    1.0
#
# [130968 rows x 8 columns]

# %%
true_plt = train_under["fraud"].value_counts()
true_plt.plot(kind="bar")
plt.show()

# %%
X_train_under = train_under.drop(columns = ["fraud"])
y_train_under = train_under["fraud"]

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train_under, y_train_under)
# Out:
# LogisticRegression()

# %%
pred = log_reg.predict(X_test_scaled)
print(classification_report(y_pred = pred, y_true = y_test))
# Out:
# C:\Users\aican\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.93      0.96    228130
#          1.0       0.58      0.95      0.72     21870
#
#     accuracy                           0.93    250000
#    macro avg       0.79      0.94      0.84    250000
# weighted avg       0.96      0.93      0.94    250000

# %%
# Accuracy dropped slightly (93%) compared to oversampling (96%).
# Precision for Fraud (Class 1) decreased (57%), meaning more false positives (incorrect fraud predictions).
# Recall for Fraud (Class 1) improved significantly (95%), meaning the model detects most actual fraud cases.
# Macro Avg Recall (94%) increased compared to oversampling (80%).

# If recall is more important, this model is the most useful.

# %%
# 6. Finally, run SMOTE in order to balance our target variable and repeat the steps above (1-3), now with balanced data. Does it improve the performance of our model?

# %%
# If recall is more important, this model is the most useful.

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state = 1,sampling_strategy=1.0)

# %%
X_train_sm,y_train_sm = sm.fit_resample(X_train_scaled,y_train)

# %%
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_sm, y_train_sm)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred = log_reg.predict(X_test_scaled)
print(classification_report(y_pred = pred, y_true = y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.93      0.96    228130
#          1.0       0.58      0.95      0.72     21870
#
#     accuracy                           0.93    250000
#    macro avg       0.78      0.94      0.84    250000
# weighted avg       0.96      0.93      0.94    250000

# %%
# Create a df after SMOTE
train_smote = pd.DataFrame(X_train_sm, columns=X_train.columns)
train_smote["fraud"] = y_train_sm.values

# %%
# Count fraud after SMOTE
smote_plt = train_smote["fraud"].value_counts()

# %%
smote_plt.plot(kind="bar")
plt.title("Class Distribution SMOTE")
plt.xlabel("Fraud (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %%
# Overall Accuracy (93%). Slightly lower than oversampling but still strong.
# Recall for Fraud (Class 1) increased significantly (95%).
# Precision for Fraud (Class 1) remains low (57%, more false positives.
# Macro Avg Recall (94%) is higher than oversampling.

# If recall is more important, this model is the most useful, together with undersample (recall 95 % in both).

# %%
# Continue in the lab-imbalance notebook and add grid search.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.20, random_state=0)

# %%
# Normalizer

# %%
normalizer = MinMaxScaler()

normalizer.fit(X_train)

# %%
X_train_norm = normalizer.transform(X_train)

X_test_norm = normalizer.transform(X_test)

# %%
X_train_norm = pd.DataFrame(X_train_norm, columns = X_train.columns)
X_test_norm = pd.DataFrame(X_test_norm, columns = X_test.columns)

# %%
# Grid Search

# %%
grid = {"n_neighbors": [3, 6, 9, 12, 15, 18]}

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
model = GridSearchCV(estimator = knn, param_grid = grid, cv=5)

# %%
model.fit(X_train_norm, y_train)

# %%
knn = KNeighborsClassifier(n_neighbors = 9)

# %%
knn.fit(X_train_norm, y_train)
knn.score(X_test_norm, y_test)

# %%
grid = {"max_depth": [3, 6, 9, 12, 15, 18]}

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = GridSearchCV(estimator = dt, param_grid = grid, cv=5)

# %%
model.fit(X-train, y_train)

# %%
model.best_params_

# %%
dt = DecisionTreeRegressor(max_depth=10)
dt.fit(X_train,y_train)

# %%
dt.score(X_test, y_test)

# %%
# After training, we check what are the best values for the hyperparameters that we have tested.

# %%
model.best_params_

# %%
# You can retrieve the best model with the best parameters when accessing best_estimator_ attribute.

# %%
best_model = model.best_estimator_

# %%
# Evaluate our model

# %%
pred = ada_reg.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", ada_reg.score(X_test_norm, y_test))
